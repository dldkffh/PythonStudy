# %% [markdown]
# ## data refine

# %%
import pandas as pd

# %%
train = pd.read_csv('../bike_sharing/train.csv', parse_dates=["datetime"])

# %%
train["datetime-year"] = train["datetime"].dt.year
train["datetime-month"] = train["datetime"].dt.month
train["datetime-day"] = train["datetime"].dt.day
train["datetime-hour"] = train["datetime"].dt.hour
train["datetime-minute"] = train["datetime"].dt.minute
train["datetime-second"] = train["datetime"].dt.second
train["datetime-dayofweek"] = train["datetime"].dt.dayofweek

# %%
train
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# 5     2011-01-01 05:00:00       1        0           0        2   9.84
# 6     2011-01-01 06:00:00       1        0           0        1   9.02
# 7     2011-01-01 07:00:00       1        0           0        1   8.20
# 8     2011-01-01 08:00:00       1        0           0        1   9.84
# 9     2011-01-01 09:00:00       1        0           0        1  13.12
# 10    2011-01-01 10:00:00       1        0           0        1  15.58
# 11    2011-01-01 11:00:00       1        0           0        1  14.76
# ...

# %%
test = pd.read_csv('../bike_sharing/test.csv', parse_dates=["datetime"])

# %%
test["datetime-year"] = test["datetime"].dt.year
test["datetime-month"] = test["datetime"].dt.month
test["datetime-day"] = test["datetime"].dt.day
test["datetime-hour"] = test["datetime"].dt.hour
test["datetime-minute"] = test["datetime"].dt.minute
test["datetime-second"] = test["datetime"].dt.second
test["datetime-dayofweek"] = test["datetime"].dt.dayofweek

# %%
test
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 0    2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 5    2011-01-20 05:00:00       1        0           1        1   9.84  11.365
# 6    2011-01-20 06:00:00       1        0           1        1   9.02  10.605
# 7    2011-01-20 07:00:00       1        0           1        1   9.02  10.605
# 8    2011-01-20 08:00:00       1        0           1        1   9.02  10.605
# 9    2011-01-20 09:00:00       1        0           1        2   9.84  11.365
# 10   2011-01-20 10:00:00       1        0           1        1  10.66  11.365
# ...

# %% [markdown]
# ## feature select

# %%
train["a+temp"] = train["temp"] + train["atemp"]
train["work-holi"] = train["workingday"] - train["holiday"]
train["temp**2"] = train["temp"]**2 
train["season**2"] = train["season"]**2
train["weather**2"] = train["weather"]**2

# %%
test["a+temp"] = test["temp"] + test["atemp"]
test["work-holi"] = test["workingday"] - test["holiday"]
test["temp**2"] = test["temp"]**2 
test["season**2"] = test["season"]**2
test["weather**2"] = test["weather"]**2

# %%
feature_names = ["season", "season**2", "work-holi", 
                 "weather","weather**2", "a+temp", "temp**2", 
                 "datetime-year", "datetime-month", "datetime-dayofweek", "datetime-hour", 
                 "windspeed", "humidity"]

# %%
feature_names
# Out:
# ['season',
#  'season**2',
#  'work-holi',
#  'weather',
#  'weather**2',
#  'a+temp',
#  'temp**2',
#  'datetime-year',
#  'datetime-month',
#  'datetime-dayofweek',
#  'datetime-hour',
#  'windspeed',
#  'humidity']

# %%
X_train = train[feature_names]
X_test = test[feature_names]

# %%
y_train = train["count"]

# %% [markdown]
# ## cross_validation

# %%
import numpy as np
from sklearn.metrics import make_scorer

# %%
def rmsle(predict, actual):
    predict = np.array(predict)
    actual=np.array(actual)
    
    log_predict = np.log(predict+1)
    log_actual = np.log(actual+1)
    
    difference = log_predict - log_actual
    difference = np.square(difference)
    
    mean_difference = difference.mean()
    
    score = np.sqrt(mean_difference)
    
    return score

rmsle_scorer = make_scorer(rmsle)
rmsle_scorer
# Out:
# make_scorer(rmsle)

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(model, X_train, y_train, cv=10, scoring=rmsle_scorer).mean()
print(score)
# Out:
# 0.41699527145019977

# %% [markdown]
# ## hyperparameters

# %% [markdown]
# ### case1 - Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %%
n_estimators = 300

max_depth_list = [5, 7, 9, 11, 13, 15]
max_features_list = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
hyperparameters_list= []
for max_depth in max_depth_list :
    for max_features in max_features_list :
        model = RandomForestRegressor(n_estimators=n_estimators,
                                     max_depth=max_depth,
                                     max_features=max_features,
                                     random_state=31,
                                     n_jobs=1)
        score = cross_val_score(model, X_train, y_train, cv=10,
                               scoring=rmsle_scorer).mean()
        hyperparameters_list.append({'Score':score, 'n_estimators':n_estimators,
                                   'max_depth':max_depth, 'max_features':max_features})
       #print("Score = {0:5f}".format(score))

hyperparameters_list
# Out:
# [{'Score': 0.8129546921866485,
#   'n_estimators': 300,
#   'max_depth': 5,
#   'max_features': 0.5},
#  {'Score': 0.7484820262341003,
#   'n_estimators': 300,
#   'max_depth': 5,
#   'max_features': 0.6},
#  {'Score': 0.6911476588379799,
#   'n_estimators': 300,
#   'max_depth': 5,
#   'max_features': 0.7},
#  {'Score': 0.673918768864431,
#   'n_estimators': 300,
#   'max_depth': 5,
#   'max_features': 0.8},
#  {'Score': 0.6640933655436353,
#   'n_estimators': 300,
#   'max_depth': 5,
#   'max_features': 0.9},
#  {'Score': 0.6543968493026509,
#   'n_estimators': 300,
#   'max_depth': 5,
#   'max_features': 1.0},
#  {'Score': 0.6545538302054709,
#   'n_estimators': 300,
#   'max_depth': 7,
#   'max_features': 0.5},
#  {'Score': 0.6088468118378348,
#   'n_estimators': 300,
#   'max_depth': 7,
#   'max_features': 0.6},
#  {'Score': 0.5598955459032877,
#   'n_estimators': 300,
#   'max_depth': 7,
#   'max_features': 0.7},
#  {'Score': 0.5467435410516752,
#   'n_estimators': 300,
# ...

# %%
hyperparameters_list = pd.DataFrame.from_dict(hyperparameters_list)
hyperparameters_list = hyperparameters_list.sort_values(by="Score")

hyperparameters_list.head()
# Out:
#        Score  max_depth  max_features  n_estimators
# 34  0.418082         15           0.9           300
# 28  0.418917         13           0.9           300
# 33  0.419300         15           0.8           300
# 27  0.420111         13           0.8           300
# 35  0.420690         15           1.0           300

# %%
hyperparameters_list
# Out:
#        Score  max_depth  max_features  n_estimators
# 34  0.418082         15           0.9           300
# 28  0.418917         13           0.9           300
# 33  0.419300         15           0.8           300
# 27  0.420111         13           0.8           300
# 35  0.420690         15           1.0           300
# 29  0.420809         13           1.0           300
# 32  0.425056         15           0.7           300
# 26  0.426196         13           0.7           300
# 22  0.426815         11           0.9           300
# 23  0.427387         11           1.0           300
# 21  0.428858         11           0.8           300
# 20  0.433797         11           0.7           300
# 31  0.449709         15           0.6           300
# 25  0.454347         13           0.6           300
# 17  0.455636          9           1.0           300
# 16  0.459791          9           0.9           300
# 15  0.461314          9           0.8           300
# ...

# %%
np.random.uniform(low=0.1, high=1.0) #나중에 위에꺼 바꿀때 쓰기
# Out:
# 0.7453735848403489

# %%
num_epoch = 10

for max_depth in (num_epoch) :
    max_depth_list = np.random.uniform(low=2, high=20) 
    max_features_list = np.random.uniform(low=0.1, high=1.0) 
        
    model = RandomForestRegressor(n_estimators=n_estimators,
                                     max_depth=max_depth,
                                     max_features=max_features,
                                     random_state=31,
                                     n_jobs=1)
    score = cross_val_score(model, X_train, y_train, cv=10,
                               scoring=rmsle_scorer).mean()
        
    hyperparameters_list.append({'Score':score, 'n_estimators':n_estimators,
                                   'max_depth':max_depth, 'max_features':max_features})
    #print("Score = {0:5f}".format(score))
        
hyperparameters_list = pd.DataFrame.from_dict(hyperparameters_list)
hyperparameters_list = hyperparameters_list.sort_values(by="Score")
        
hyperparameters_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-199-eb0433c3215f> in <module>
#       1 num_epoch = 10
#       2
# ----> 3 for max_depth in (num_epoch) :
#       4     max_depth_list = np.random.uniform(low=2, high=20)
#       5     max_features_list = np.random.uniform(low=0.1, high=1.0)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# ## EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(18, 8)

sns.barplot(data=train, x="datetime-year", y="count", ax=ax1) #차이가 상당, 꼭 써야함
sns.barplot(data=train, x="datetime-month", y="count", ax=ax2)
sns.barplot(data=train, x="datetime-day", y="count", ax=ax3) #20일까지 밖에 없음, 사용하면 안됨
sns.barplot(data=train, x="datetime-hour", y="count", ax=ax4)
sns.barplot(data=train, x="datetime-minute", y="count", ax=ax5) #기록 안됨, 버려
sns.barplot(data=train, x="datetime-second", y="count", ax=ax6) #기록 안됨, 버려 
#datetime-dayofweek 는 별로 중요하지 않음
# Out:
# C:\Users\163908\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pointplot(data=train, x="datetime-hour", y="count", hue="workingday")

# %%
sns.pointplot(data=train, x="datetime-hour", y="count", hue="holiday")

# %%
sns.pointplot(data=train, x="datetime-hour", y="count", hue="work-holi")

# %%
sns.pointplot(data=train, x="datetime-hour", y="count", hue="datetime-dayofweek")

# %%
#year와 month를 합쳐서 보자

def concat_year_month(datetime) :
    return "{0}-{1}".format(datetime.year, datetime.month) #format : 인자를 집어 넣는다

# %%
train["year-month"] = train["datetime"].apply(concat_year_month)
train[["datetime", "year-month"]].head()
# Out:
#              datetime year-month
# 0 2011-01-01 00:00:00     2011-1
# 1 2011-01-01 01:00:00     2011-1
# 2 2011-01-01 02:00:00     2011-1
# 3 2011-01-01 03:00:00     2011-1
# 4 2011-01-01 04:00:00     2011-1

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(18,4)
sns.barplot(data=train, x="datetime-year", y="count", ax=ax1)
sns.barplot(data=train, x="datetime-month", y="count", ax=ax2)

figure, (ax3) = plt.subplots(nrows=1, ncols=1) #긴거!!!
figure.set_size_inches(18,4)
sns.barplot(data=train, x="year-month", y="count", ax=ax3)
# Out:
# C:\Users\163908\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
figure.set_size_inches(18,4)
sns.barplot(data=train, x="weather", y="count", ax=ax1)
sns.barplot(data=train, x="season", y="count", ax=ax2)
sns.barplot(data=train, x=train["weather"]+train["season"], y="count", ax=ax3) #날씨와 계절은 궁합이 별로

# %%
import matplotlib.pyplot as plt

# %%
badfeel = 0.72 * ((train["temp"]+train["atemp"])/2+train["humidity"]) + 40.6

# %%
figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
figure.set_size_inches(18,4)
sns.pointplot(data=train, x="windspeed", y="count", ax=ax1)
sns.pointplot(data=train, x="humidity", y="count", ax=ax2)
sns.pointplot(data=train, x=train["windspeed"]-train["humidity"], y="count", ax=ax3) #궁합이 별로

# %%
sns.pointplot(data=train, x=train["windspeed"]*train["humidity"], y="count")

# %% [markdown]
# ## fit / predict

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=1000, max_depth=15, max_features=0.9, random_state=31, n_jobs=1)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=15,
#            max_features=0.9, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#            oob_score=False, random_state=31, verbose=0, warm_start=False)

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([ 11.73027848,   5.42737882,   4.32845973, ..., 150.11870363,
#        113.4508649 ,  65.17539685])

# %% [markdown]
# ## XGBooting

# %%
XGBmodel=XGBClassifier(booster='gbtree', 
                    colsample_bylevel=0.9, 
                    colsample_bytree=0.8, 
                    gamma=0, 
                    max_depth=8, 
                    min_child_weight=3, 
                    n_estimators=50, 
                    nthread=4, 
                    objective='binary:logistic', 
                    random_state=2, 
                    silent= True)

XGBmodel.fit(train_X,train_Y, eval_set=[(val_X,val_Y)],
             early_stopping_rounds=50,verbos=5)

XGBmodel.predict(test_X)

# %% [markdown]
# ## save / submission

# %%
submission = pd.read_csv('../bike_sharing/sampleSubmission.csv')
submission["count"] = predictions
submission.to_csv("BikeSubmission2.csv", index=False)
